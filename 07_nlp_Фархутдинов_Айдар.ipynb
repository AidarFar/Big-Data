# %% [markdown]
# # Введение в обработку текста на естественном языке

# %% [markdown]
# __Автор задач: Блохин Н.В. (NVBlokhin@fa.ru)__
#
# Материалы:
# * Макрушин С.В. Лекция "Введение в обработку текста на естественном языке"
# * https://www.nltk.org/api/nltk.metrics.distance.html
# * https://pymorphy2.readthedocs.io/en/stable/user/guide.html
# * https://realpython.com/nltk-nlp-python/
# * https://scikit-learn.org/stable/modules/feature_extraction.html

# %% [markdown]
# ## Задачи для совместного разбора

# %%
# !pip install pymorphy2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.3 MB/s
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting docopt>=0.6
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      |████████████████████████████████| 8.2 MB 11.0 MB/s
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=1741ba4ddf371e51fad3c6406171c64dfbcd5bc1a16a025af63924443dc9da73
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built docopt
# Installing collected packages: pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# 1. Считайте слова из файла `litw-win.txt` и запишите их в список `words`. При помощи расстояния Левенштейна иправьте опечатку в слове "велечайшим".

# %%
from nltk import edit_distance

# %% [markdown]
# 2. Разбейте текст из формулировки второго задания на слова. Проведите стемминг и лемматизацию слов.

# %%
from nltk.stem import SnowballStemmer
from nltk import word_tokenize
import pymorphy2

# %%
text = '''Разбейте текст из формулировки второго задания на слова. Проведите стемминг и лемматизацию слов.'''

# %% [markdown]
# 3. Преобразуйте предложения из формулировки задания 2 в векторы при помощи `CountVectorizer`. Выведите на экран словарь обученного токенизатора.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk import sent_tokenize

# %%
text = '''Разбейте текст из формулировки второго задания на слова. Проведите стемминг и лемматизацию слов.'''

# %% [markdown]
# ## Лабораторная работа 7

# %% [markdown]
# 1\. Загрузите данные из файла `ru_recipes_sample.csv` в виде `pd.DataFrame` `recipes` Используя регулярные выражения, удалите из описаний (столбец `description`) все символы, кроме русских букв, цифр и пробелов. Приведите все слова в описании к нижнему регистру. Сохраните полученный результат в столбец `description`.

# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
rec_df = pd.read_csv('/content/drive/MyDrive/ru_recipes_sample.csv')
rec_df
# Out:
#                                                 url  \
# 0     https://www.povarenok.ru/recipes/show/164365/
# 1       https://www.povarenok.ru/recipes/show/1306/
# 2      https://www.povarenok.ru/recipes/show/10625/
# 3     https://www.povarenok.ru/recipes/show/167337/
# 4      https://www.povarenok.ru/recipes/show/91919/
# ...                                             ...
# 3462   https://www.povarenok.ru/recipes/show/54574/
# 3463  https://www.povarenok.ru/recipes/show/113494/
# 3464   https://www.povarenok.ru/recipes/show/83228/
# 3465  https://www.povarenok.ru/recipes/show/172238/
# 3466   https://www.povarenok.ru/recipes/show/52794/
#
#                                                    name  \
# 0                    Густой молочно-клубничный коктейль
# 1                                              Рулетики
# 2                                   Салат "Баклажанчик"
# 3         Куриные котлеты с картофельным пюре в духовке
# 4                               Рецепт вишневой наливки
# ...                                                 ...
# 3462                                               Мшош
# 3463                   Мясные треугольники с баклажаном
# 3464                               "Болоньез" по-новому
# 3465               Варенье из одуванчиков с апельсинами
# 3466  Три корочки хлеба под соусом болоньез для Пино...
#
#                                             ingredients  \
# 0     {'Молоко': '250 мл', 'Клубника': '200 г', 'Сах...
# 1     {'Сыр твердый': None, 'Чеснок': None, 'Яйцо ку...
# 2     {'Баклажан': '3 шт', 'Лук репчатый': '2 шт', '...
# 3     {'Фарш куриный': '800 г', 'Пюре картофельное':...
# 4     {'Вишня': '1 кг', 'Водка': '1 л', 'Сахар': '30...
# ...                                                 ...
# 3462  {'Чечевица': '1 стак.', 'Лук репчатый': '2 шт'...
# 3463  {'Фарш мясной': '400 г', 'Баклажан': '1 шт', '...
# 3464  {'Фарш мясной': '400 г', 'Томаты в собственном...
# 3465  {'Цветки': '400 г', 'Сахар': '1300 г', 'Апельс...
# 3466  {'Хлеб': '3 шт', 'Фарш мясной': '200-250 г', '...
#
#                                             description
# 0     Этот коктейль готовлю из замороженной клубники...
# 1                                      Быстро и вкусно.
# 2           Сытный, овощной салатик, пальчики оближете.
# 3     Картофельное пюре и куриные котлеты - вкусная ...
# 4     Вишневая наливка имеет яркий вишневый вкус, ко...
# ...                                                 ...
# 3462  Для тех, кто любит чечевицу... Вам сюда! Очень...
# 3463  Баклажановые фантазии продолжаются! Предлагаю ...
# 3464  Мое любимое блюдо лазанья. Но кушать только фа...
# 3465  Прошлым летом варила варенье из одуванчиков по...
# 3466  - И три корочки хлеба! - сделал заказ Буратино...
#
# [3467 rows x 4 columns]

# %%
rec_df['description'] = rec_df['description'].str.lower()
rec_df.replace({'description':"[^а-яё0-9\s]"},{'description':""},regex=True, inplace = True)

# %%
rec_df
# Out:
#                                                 url  \
# 0     https://www.povarenok.ru/recipes/show/164365/
# 1       https://www.povarenok.ru/recipes/show/1306/
# 2      https://www.povarenok.ru/recipes/show/10625/
# 3     https://www.povarenok.ru/recipes/show/167337/
# 4      https://www.povarenok.ru/recipes/show/91919/
# ...                                             ...
# 3462   https://www.povarenok.ru/recipes/show/54574/
# 3463  https://www.povarenok.ru/recipes/show/113494/
# 3464   https://www.povarenok.ru/recipes/show/83228/
# 3465  https://www.povarenok.ru/recipes/show/172238/
# 3466   https://www.povarenok.ru/recipes/show/52794/
#
#                                                    name  \
# 0                    Густой молочно-клубничный коктейль
# 1                                              Рулетики
# 2                                   Салат "Баклажанчик"
# 3         Куриные котлеты с картофельным пюре в духовке
# 4                               Рецепт вишневой наливки
# ...                                                 ...
# 3462                                               Мшош
# 3463                   Мясные треугольники с баклажаном
# 3464                               "Болоньез" по-новому
# 3465               Варенье из одуванчиков с апельсинами
# 3466  Три корочки хлеба под соусом болоньез для Пино...
#
#                                             ingredients  \
# 0     {'Молоко': '250 мл', 'Клубника': '200 г', 'Сах...
# 1     {'Сыр твердый': None, 'Чеснок': None, 'Яйцо ку...
# 2     {'Баклажан': '3 шт', 'Лук репчатый': '2 шт', '...
# 3     {'Фарш куриный': '800 г', 'Пюре картофельное':...
# 4     {'Вишня': '1 кг', 'Водка': '1 л', 'Сахар': '30...
# ...                                                 ...
# 3462  {'Чечевица': '1 стак.', 'Лук репчатый': '2 шт'...
# 3463  {'Фарш мясной': '400 г', 'Баклажан': '1 шт', '...
# 3464  {'Фарш мясной': '400 г', 'Томаты в собственном...
# 3465  {'Цветки': '400 г', 'Сахар': '1300 г', 'Апельс...
# 3466  {'Хлеб': '3 шт', 'Фарш мясной': '200-250 г', '...
#
#                                             description
# 0     этот коктейль готовлю из замороженной клубники...
# 1                                       быстро и вкусно
# 2              сытный овощной салатик пальчики оближете
# 3     картофельное пюре и куриные котлеты  вкусная к...
# 4     вишневая наливка имеет яркий вишневый вкус кот...
# ...                                                 ...
# 3462  для тех кто любит чечевицу вам сюда очень вкус...
# 3463  баклажановые фантазии продолжаются предлагаю в...
# 3464  мое любимое блюдо лазанья но кушать только фар...
# 3465  прошлым летом варила варенье из одуванчиков по...
# 3466   и три корочки хлеба  сделал заказ буратино в ...
#
# [3467 rows x 4 columns]

# %% [markdown]
# ### Расстояние редактирования

# %% [markdown]
# 2\. Получите набор уникальных слов `words`, содержащихся в текстах описаний рецептов (воспользуйтесь `word_tokenize` из `nltk`). Сгенерируйте 5 пар случайно выбранных слов и посчитайте между ними расстояние Левенштейна. Выведите на экран результат в следующем виде:
#
# ```
# d(word1, word2) = x
# ```

# %%
# rec_df['description'] = (rec_df['description'].apply(word_tokenize))

# %%
# words = set()
# for i in rec_df['description']:
#   words.update(i)
# words
# len(words)

# %%
# import random
# print(random.sample(words, 3))

# %%
# !pip install Levenshtein
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Levenshtein
#   Downloading Levenshtein-0.20.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (174 kB)
#      |████████████████████████████████| 174 kB 5.2 MB/s
# Collecting rapidfuzz<3.0.0,>=2.3.0
#   Downloading rapidfuzz-2.13.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 37.1 MB/s
# Installing collected packages: rapidfuzz, Levenshtein
# Successfully installed Levenshtein-0.20.8 rapidfuzz-2.13.7

# %%
from Levenshtein import distance as lev
import random

# %%
words = word_tokenize(rec_df.description.to_string(index=False))
words = [i for i in words if i != '...']
rand_index = random.sample(words,10)
print(rand_index)
for i in range(0,9,2):
    print(f"d({rand_index[i]}, {rand_index[i+1]}) = {lev(rand_index[i], rand_index[i+1])}")
# Out:
# ['было', 'с', 'прекрасный', 'мясная', 'нете', 'без', 'курочка', 'пряное', 'приготовить', 'привет']
# d(было, с) = 4
# d(прекрасный, мясная) = 8
# d(нете, без) = 3
# d(курочка, пряное) = 6
# d(приготовить, привет) = 6

# %% [markdown]
# 3\. Напишите функцию, которая принимает на вход 2 текстовые строки `s1` и `s2` и при помощи расстояния Левенштейна определяет, является ли строка `s2` плагиатом `s1`. Функция должна реализовывать следующую логику: для каждого слова `w1` из `s1` проверяет, есть в `s2` хотя бы одно слово `w2`, такое, что расстояние Левенштейна между `w1` и `w2` меньше 2, и считает количество таких слов в `s1` $P$.
#
# $$ P = \#\{w_1 \in s_1\ | \exists w_2 \in s_2 : d(w_1, w_2) < tol\}$$
#
# $$ L = max(|s1|, |s2|) $$
#
# Здесь $|\cdot|$ - количество слов в строке, $\#A$ - число элементов в множестве $A$, $w \in s$ означает, что слово $w$ содержится в тексте $s$.
#
# Если отношение $P / L$ больше 0.8, то функция должна вернуть True; иначе False.
#
# Продемонстрируйте работу вашей функции на примере описаний двух рецептов с ID 135488 и 851934 (ID рецепта - это число, стоящее в конце url рецепта). Выведите на экран описания этих рецептов и результат работы функции.

# %%
def is_plagiarism(s1: str, s2: str) -> bool:
    count=0
    s1 = word_tokenize(s1)
    s2 = word_tokenize(s2)
    for w1 in s1:
        for w2 in s2:
            count += 1 if lev(w1, w2) < 2 else 0
    L = max(len(s1), len(s2))
    return True if count/L > 0.8 else False

# %%
a = rec_df[rec_df['url']=='https://www.povarenok.ru/recipes/show/135488/']['description'].astype(str).to_string()
b = rec_df[rec_df['url']=='https://www.povarenok.ru/recipes/show/851934/']['description'].astype(str).to_string()
print(is_plagiarism(a,b))
print(a)
print(b)
# Out:
# False
# 958    прекрасной закуской к крепким напиткам на фурш...
# 1473    замечательной закуской к напиткам на фуршетном...

# %% [markdown]
# ### Стемминг, лемматизация

# %% [markdown]
# 4\. На основе набора слов из задания 2 создайте `pd.DataFrame` со столбцами `word`, `stemmed_word` и `normalized_word`. В столбец `stemmed_word` поместите версию слова после проведения процедуры стемминга; в столбец `normalized_word` поместите версию слова после проведения процедуры лемматизации. Столбец `word` укажите в качестве индекса.
#
# Для стемминга можно воспользоваться `SnowballStemmer` из `nltk`, для лемматизации слов - пакетом `pymorphy2`. Сравните результаты стемминга и лемматизации. Поясните на примере одной из строк получившегося фрейма (в виде текстового комментария), в чем разница между двумя этими подходами.

# %%
from nltk import SnowballStemmer
import pymorphy2

# %%
snowball = SnowballStemmer("russian")
df = pd.DataFrame(data=[snowball.stem(w) for w in words], columns=['stemmed_word'], index=words)
morph = pymorphy2.MorphAnalyzer()
df['normalized_word'] = [morph.parse(w)[0].normal_form for w in words]
df
# Out:
#              stemmed_word normalized_word
# этот                 этот            этот
# коктейль          коктейл        коктейль
# готовлю            готовл        готовить
# из                     из              из
# замороженной    заморожен      заморозить
# ...                   ...             ...
# сделал              сдела         сделать
# заказ               заказ           заказ
# буратино          буратин        буратино
# в                       в               в
# т                       т             так
#
# [24850 rows x 2 columns]

# %% [markdown]
# 5\. Добавьте в таблицу `recipes` столбец `description_no_stopwords`, в котором содержится текст описания рецепта после удаления из него стоп-слов. Посчитайте и выведите на экран долю стоп-слов среди общего количества слов. Сравните топ-10 самых часто употребляемых слов до и после удаления стоп-слов.

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords = nltk.corpus.stopwords.words("russian")
rec_df['description_no_stopwords'] = rec_df.description.apply(lambda x: ' '.join([i for i in word_tokenize(x) if i not in stopwords]))
rec_df
# Out:
#                                                 url  \
# 0     https://www.povarenok.ru/recipes/show/164365/
# 1       https://www.povarenok.ru/recipes/show/1306/
# 2      https://www.povarenok.ru/recipes/show/10625/
# 3     https://www.povarenok.ru/recipes/show/167337/
# 4      https://www.povarenok.ru/recipes/show/91919/
# ...                                             ...
# 3462   https://www.povarenok.ru/recipes/show/54574/
# 3463  https://www.povarenok.ru/recipes/show/113494/
# 3464   https://www.povarenok.ru/recipes/show/83228/
# 3465  https://www.povarenok.ru/recipes/show/172238/
# 3466   https://www.povarenok.ru/recipes/show/52794/
#
#                                                    name  \
# 0                    Густой молочно-клубничный коктейль
# 1                                              Рулетики
# 2                                   Салат "Баклажанчик"
# 3         Куриные котлеты с картофельным пюре в духовке
# 4                               Рецепт вишневой наливки
# ...                                                 ...
# 3462                                               Мшош
# 3463                   Мясные треугольники с баклажаном
# 3464                               "Болоньез" по-новому
# 3465               Варенье из одуванчиков с апельсинами
# 3466  Три корочки хлеба под соусом болоньез для Пино...
#
#                                             ingredients  \
# 0     {'Молоко': '250 мл', 'Клубника': '200 г', 'Сах...
# 1     {'Сыр твердый': None, 'Чеснок': None, 'Яйцо ку...
# 2     {'Баклажан': '3 шт', 'Лук репчатый': '2 шт', '...
# 3     {'Фарш куриный': '800 г', 'Пюре картофельное':...
# 4     {'Вишня': '1 кг', 'Водка': '1 л', 'Сахар': '30...
# ...                                                 ...
# 3462  {'Чечевица': '1 стак.', 'Лук репчатый': '2 шт'...
# 3463  {'Фарш мясной': '400 г', 'Баклажан': '1 шт', '...
# 3464  {'Фарш мясной': '400 г', 'Томаты в собственном...
# 3465  {'Цветки': '400 г', 'Сахар': '1300 г', 'Апельс...
# 3466  {'Хлеб': '3 шт', 'Фарш мясной': '200-250 г', '...
#
#                                             description  \
# 0     этот коктейль готовлю из замороженной клубники...
# 1                                       быстро и вкусно
# 2              сытный овощной салатик пальчики оближете
# 3     картофельное пюре и куриные котлеты  вкусная к...
# 4     вишневая наливка имеет яркий вишневый вкус кот...
# ...                                                 ...
# 3462  для тех кто любит чечевицу вам сюда очень вкус...
# 3463  баклажановые фантазии продолжаются предлагаю в...
# 3464  мое любимое блюдо лазанья но кушать только фар...
# 3465  прошлым летом варила варенье из одуванчиков по...
# 3466   и три корочки хлеба  сделал заказ буратино в ...
#
#                                description_no_stopwords
# 0     коктейль готовлю замороженной клубники клубник...
# 1                                         быстро вкусно
# 2              сытный овощной салатик пальчики оближете
# 3     картофельное пюре куриные котлеты вкусная клас...
# 4     вишневая наливка имеет яркий вишневый вкус кот...
# ...                                                 ...
# 3462  тех любит чечевицу сюда очень вкусная чечевичн...
# 3463  баклажановые фантазии продолжаются предлагаю в...
# 3464  мое любимое блюдо лазанья кушать фарш поднадое...
# 3465  прошлым летом варила варенье одуванчиков рецеп...
# 3466  корочки хлеба сделал заказ буратино таверне до...
#
# [3467 rows x 5 columns]

# %%
all_words = rec_df['description'].map(str.split).explode().value_counts()
all_words.head(10)
# Out:
# и         5054
# в         2584
# с         1934
# на        1655
# очень     1607
# не        1517
# из        1006
# я          979
# рецепт     869
# а          863
# Name: description, dtype: int64

# %%
without_garb_words = rec_df['description_no_stopwords'].map(str.split).explode().value_counts()
without_garb_words.head(10)
# Out:
# очень          1607
# рецепт          869
# это             734
# блюдо           524
# вкусный         461
# просто          436
# вкусно          375
# приготовить     344
# вкус            324
# салат           313
# Name: description_no_stopwords, dtype: int64

# %%
f"{100-len(without_garb_words)/len(all_words)*100} %"
# Out:
# '0.9178773326849523 %'

# %% [markdown]
# ### Векторное представление текста

# %% [markdown]
# 6\. Выберите случайным образом 5 рецептов из набора данных, в названии которых есть слово "оладьи" (без учета регистра). Представьте описание каждого рецепта в виде числового вектора при помощи `TfidfVectorizer`. На основе полученных векторов создайте `pd.DataFrame`, в котором названия колонок соответствуют словам из словаря объекта-векторизатора.
#
# Примечание: обратите внимание на порядок слов при создании колонок.

# %%
ol = rec_df[rec_df['description'].str.contains('оладьи')].sample(5)
ol
# Out:
#                                                 url  \
# 2034  https://www.povarenok.ru/recipes/show/116312/
# 582    https://www.povarenok.ru/recipes/show/21235/
# 2506   https://www.povarenok.ru/recipes/show/57827/
# 599    https://www.povarenok.ru/recipes/show/83639/
# 2382  https://www.povarenok.ru/recipes/show/132232/
#
#                              name  \
# 2034      Оладьи кукурузно-сырные
# 582   Драники "Дружеский хоровод"
# 2506        Нежные куриные оладьи
# 599    Оладьи из брокколи с сыром
# 2382               Пюре тыквенное
#
#                                             ingredients  \
# 2034  {'Кукуруза': '1 бан.', 'Мука пшеничная': '2 ст...
# 582   {'Картофель': None, 'Лук репчатый': None, 'Кап...
# 2506  {'Филе куриное': '500 г', 'Сыр плавленый': '2 ...
# 599   {'Брокколи': '250 г', 'Сыр твердый': '50 г', '...
# 2382                   {'Тыква': '1 шт', 'Вода': '1 л'}
#
#                                             description  \
# 2034  опять в продолжение темы друзья оладьи чудесны...
# 582   поиски по энциклопедии вот что дали\r\nдраники...
# 2506   нежные сочные оладьи и очень очень очень вкусные
# 599   оладьи из брокколи и сыра сытно а как вкусно е...
# 2382  в сезон тыквы мы готовим блюда из неё но к сож...
#
#                                description_no_stopwords
# 2034  продолжение темы друзья оладьи чудесные вспомн...
# 582   поиски энциклопедии дали драники картофельные ...
# 2506     нежные сочные оладьи очень очень очень вкусные
# 599   оладьи брокколи сыра сытно вкусно подать оладь...
# 2382  сезон тыквы готовим блюда неё сожалению очень ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfv = TfidfVectorizer()
vec = tfv.fit_transform(ol['description'])
vecm = vec.todense()
olad = pd.DataFrame(data = vecm, columns = tfv.get_feature_names_out(), index = ol['name'])
olad
# Out:
#                                    57     банку  безобразия  белорусской  \
# name
# Оладьи кукурузно-сырные      0.000000  0.000000    0.000000     0.000000
# Драники "Дружеский хоровод"  0.000000  0.000000    0.000000     0.182787
# Нежные куриные оладьи        0.000000  0.000000    0.000000     0.000000
# Оладьи из брокколи с сыром   0.000000  0.000000    0.000000     0.000000
# Пюре тыквенное               0.112376  0.112376    0.112376     0.000000
#
#                                 блюда     блюдо  брокколи     будут    быстро  \
# name
# Оладьи кукурузно-сырные      0.000000  0.115095  0.000000  0.142657  0.000000
# Драники "Дружеский хоровод"  0.000000  0.147471  0.000000  0.000000  0.000000
# Нежные куриные оладьи        0.000000  0.000000  0.000000  0.000000  0.000000
# Оладьи из брокколи с сыром   0.000000  0.000000  0.267188  0.000000  0.000000
# Пюре тыквенное               0.112376  0.000000  0.000000  0.000000  0.112376
#
#                                   вам  ...  украинской     уютно     часто  \
# name                                   ...
# Оладьи кукурузно-сырные      0.000000  ...    0.000000  0.142657  0.000000
# Драники "Дружеский хоровод"  0.000000  ...    0.182787  0.000000  0.000000
# Нежные куриные оладьи        0.000000  ...    0.000000  0.000000  0.000000
# Оладьи из брокколи с сыром   0.000000  ...    0.000000  0.000000  0.000000
# Пюре тыквенное               0.112376  ...    0.000000  0.000000  0.112376
#
#                                 часть    чистую       что  чудесные  \
# name
# Оладьи кукурузно-сырные      0.000000  0.000000  0.115095  0.142657
# Драники "Дружеский хоровод"  0.000000  0.000000  0.294943  0.000000
# Нежные куриные оладьи        0.000000  0.000000  0.000000  0.000000
# Оладьи из брокколи с сыром   0.000000  0.000000  0.000000  0.000000
# Пюре тыквенное               0.112376  0.112376  0.000000  0.000000
#
#                              энциклопедии       это     этого
# name
# Оладьи кукурузно-сырные          0.000000  0.000000  0.000000
# Драники "Дружеский хоровод"      0.182787  0.182787  0.182787
# Нежные куриные оладьи            0.000000  0.000000  0.000000
# Оладьи из брокколи с сыром       0.000000  0.000000  0.000000
# Пюре тыквенное                   0.000000  0.000000  0.000000
#
# [5 rows x 134 columns]

# %% [markdown]
# 7\. Вычислите близость между каждой парой рецептов, выбранных в задании 6, используя косинусное расстояние (можно воспользоваться функциями из любого пакета: `scipy`, `scikit-learn` или реализовать функцию самому). Результаты оформите в виде таблицы `pd.DataFrame`. В качестве названий строк и столбцов используйте названия рецептов.
#
# Примечание: обратите внимание, что $d_{cosine}(x, x) = 0$

# %%
from sklearn.metrics.pairwise import cosine_distances

# %%
cos_dis = pd.DataFrame(data=cosine_distances(olad, olad), index=ol['name'], columns=ol['name'])
cos_dis
# Out:
# name                         Оладьи кукурузно-сырные  \
# name
# Оладьи кукурузно-сырные                     0.000000
# Драники "Дружеский хоровод"                 0.943160
# Нежные куриные оладьи                       0.879371
# Оладьи из брокколи с сыром                  0.982691
# Пюре тыквенное                              0.853514
#
# name                         Драники "Дружеский хоровод"  \
# name
# Оладьи кукурузно-сырные                         0.943160
# Драники "Дружеский хоровод"                     0.000000
# Нежные куриные оладьи                           0.984217
# Оладьи из брокколи с сыром                      0.955917
# Пюре тыквенное                                  0.976910
#
# name                         Нежные куриные оладьи  \
# name
# Оладьи кукурузно-сырные                   0.879371
# Драники "Дружеский хоровод"               0.984217
# Нежные куриные оладьи                     0.000000
# Оладьи из брокколи с сыром                0.953858
# Пюре тыквенное                            0.932794
#
# name                         Оладьи из брокколи с сыром  Пюре тыквенное
# name
# Оладьи кукурузно-сырные                        0.982691        0.853514
# Драники "Дружеский хоровод"                    0.955917        0.976910
# Нежные куриные оладьи                          0.953858        0.932794
# Оладьи из брокколи с сыром                     0.000000        0.939887
# Пюре тыквенное                                 0.939887        0.000000

# %% [markdown]
# 8\. Напишите функцию, которая принимает на вход `pd.DataFrame`, полученный в задании 7, и возвращает в виде кортежа названия двух различных рецептов, которые являются наиболее похожими. Прокомментируйте результат (в виде текстового комментария). Для объяснения результата сравните слова в описаниях двух этих отзывов.

# %%
def find_closest(sim_df: pd.DataFrame) -> tuple:
    return tuple(sim_df[sim_df == sim_df.max().max()].dropna(how='all').dropna(axis=1,how='all').columns)
find_closest(cos_dis)
# Out:
# ('Драники "Дружеский хоровод"', 'Нежные куриные оладьи')
